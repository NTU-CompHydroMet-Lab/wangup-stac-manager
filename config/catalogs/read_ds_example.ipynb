# %%
import intake

catalog = intake.open_catalog("glofas_intake_catalog.yaml")

ds = catalog["glofas_return_periods"].to_dask()

# %%
ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:    (latitude: 3000, longitude: 7200)
# Coordinates:
#   * latitude   (latitude) float64 24kB 89.97 89.92 89.88 ... -59.92 -59.98
#   * longitude  (longitude) float64 58kB -180.0 -179.9 -179.9 ... 179.9 180.0
#     surface    float64 8B ...
# Data variables:
#     T_2        (latitude, longitude) float64 173MB dask.array<chunksize=(750, 1800), meta=np.ndarray>
#     T_5        (latitude, longitude) float64 173MB dask.array<chunksize=(750, 1800), meta=np.ndarray>
#     T_10       (latitude, longitude) float64 173MB dask.array<chunksize=(750, 1800), meta=np.ndarray>
#     T_20       (latitude, longitude) float64 173MB dask.array<chunksize=(750, 1800), meta=np.ndarray>
#     T_50       (latitude, longitude) float64 173MB dask.array<chunksize=(750, 1800), meta=np.ndarray>
#     T_100      (latitude, longitude) float64 173MB dask.array<chunksize=(750, 1800), meta=np.ndarray>
# ...

# %%
print(ds)
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:    (latitude: 3000, longitude: 7200)
# Coordinates:
#   * latitude   (latitude) float64 24kB 89.97 89.92 89.88 ... -59.92 -59.98
#   * longitude  (longitude) float64 58kB -180.0 -179.9 -179.9 ... 179.9 180.0
#     surface    float64 8B ...
# Data variables:
#     T_2        (latitude, longitude) float64 173MB dask.array<chunksize=(750, 1800), meta=np.ndarray>
#     T_5        (latitude, longitude) float64 173MB dask.array<chunksize=(750, 1800), meta=np.ndarray>
#     T_10       (latitude, longitude) float64 173MB dask.array<chunksize=(750, 1800), meta=np.ndarray>
#     T_20       (latitude, longitude) float64 173MB dask.array<chunksize=(750, 1800), meta=np.ndarray>
#     T_50       (latitude, longitude) float64 173MB dask.array<chunksize=(750, 1800), meta=np.ndarray>
#     T_100      (latitude, longitude) float64 173MB dask.array<chunksize=(750, 1800), meta=np.ndarray>
# ...
